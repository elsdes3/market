# %% [markdown]
# # Cleanup Google Cloud Resources

# %% [markdown]
# ::: {.content-hidden}
# Import necessary Python modules
# :::

# %%
import os
import sys
from glob import glob

import pandas as pd
from google.cloud import bigquery, storage
from google.oauth2 import service_account

# %% [markdown]
# ::: {.content-hidden}
# Get relative path to project root directory
# :::

# %%
PROJ_ROOT_DIR = os.path.join(os.pardir)

# %% [markdown]
# ## About

# %% [markdown]
# ### Overview
# This step deletes all Google Cloud resources that were created during this project. This includes
#
# 1. BigQuery [tables](https://cloud.google.com/bigquery/docs/tables-intro) in the [dataset](https://cloud.google.com/bigquery/docs/datasets-intro) that was manually created as part of the pre-requisites for this project
# 2. Storage [bucket](https://cloud.google.com/storage/docs/json_api/v1/buckets)
#
# ### Order of Operations
# This step can be run at the end of the project, after the campaign has ended and its outcomes have been analyzed.

# %% [markdown]
# ## User Inputs

# %% [markdown]
# Define the following GCP resources
#
# 1. BigQuery
#    - dataset id
#    - table ids for
#      - raw GA360 data
#      - audience
#        - cohorts
#        - profile
# 2. GCS bucket name

# %%
#| echo: true
# 1. Bigquery resources
gbq_dataset_id = 'mydemo2asdf'
gbq_table_id_raw_data = 'ecwa'
gbq_table_id_cohorts = 'audience_cohorts'
gbq_table_id_profiles = 'audience_profiles'

# 2. GCS bucket name
bucket_name = "ecwa-raw"

# %% [markdown]
# ::: {.content-hidden}
# Get path to data sub-folders
# :::

# %%
data_dir = os.path.join(PROJ_ROOT_DIR, "data")
raw_data_dir = os.path.join(data_dir, "raw")

# %% [markdown]
# ::: {.content-hidden}
# Load Google Cloud authentication credentials for use with the native Google Python client
# :::

# %%
gcp_proj_id = os.environ["GCP_PROJECT_ID"]
gcp_creds_fpath = glob(os.path.join(raw_data_dir, "*.json"))[0]
gcp_creds = service_account.Credentials.from_service_account_file(
    gcp_creds_fpath
)

# %% [markdown]
# ::: {.content-hidden}
# Get path to all raw data files that were previously exported
# :::

# %%
raw_data_files = sorted(glob(os.path.join(raw_data_dir, "ga_data", "*.parquet.gzip")))

# %% [markdown]
# ::: {.content-hidden}
# Create authenticated native BigQuery Python client
# :::

# %%
client = bigquery.Client(project=gcp_proj_id, credentials=gcp_creds)

# %% [markdown]
# ::: {.content-hidden}
# Create authenticated native GCS Python client
# :::

# %%
storage_client = storage.Client(project=gcp_proj_id, credentials=gcp_creds)

# %% [markdown]
# ## Cleanup BigQuery

# %% [markdown]
# ### Tables

# %% [markdown]
# [Delete BigQuery table](https://cloud.google.com/bigquery/docs/samples/bigquery-delete-table#code-sample)s

# %%
#| echo: true
for gbq_table_id in [
    gbq_table_id_raw_data, gbq_table_id_cohorts, gbq_table_id_profiles
]:
    gbq_table_fully_resolved = f"{gcp_proj_id}.{gbq_dataset_id}.{gbq_table_id}"
    client.delete_table(gbq_table_fully_resolved)
    print(f"Deleted table {gbq_table_fully_resolved}")
# Out:
# Deleted table demoabc-381618.mydemo2asdf.ecwa
# Deleted table demoabc-381618.mydemo2asdf.audience_cohorts
# Deleted table demoabc-381618.mydemo2asdf.audience_profiles

# %% [markdown]
# ## Cleanup Storage

# %% [markdown]
# ### Files

# %% [markdown]
# [List files in specified bucket](https://github.com/googleapis/python-storage/blob/main/samples/snippets/storage_list_files.py)

# %%
blobs = list(storage_client.list_blobs(bucket_name))
if blobs:
    df_blobs = (
        pd.DataFrame.from_records(
            [
                {
                    "name": b.name,
                    "bucket": b.bucket.name,
                    "size_mb": b.size / 1_000_000,
                    "id": b.id,
                    "time_created": b.time_created,
                }
                for b in blobs
            ]
        )
        .assign(time_created=lambda df: df['time_created'].dt.tz_convert('US/Eastern'))
    )
    print(
        f"Showing {len(df_blobs):,} files found in bucket {bucket_name}, "
        f"taking up {df_blobs['size_mb'].sum():.1f} MB of space"
    )
    with pd.option_context('display.max_colwidth', None):
        display(df_blobs)
else:
    print(f"Found no files in bucket {bucket_name}")
# Out:
# Showing 55 files found in bucket ecwa-raw, taking up 225.4 MB of space
#                                                           name    bucket  \
# 0   d2i_ecwa__20160801__20160807__20230611_200354.parquet.gzip  ecwa-raw
# 1   d2i_ecwa__20160808__20160814__20230611_200726.parquet.gzip  ecwa-raw
# 2   d2i_ecwa__20160815__20160821__20230611_201100.parquet.gzip  ecwa-raw
# 3   d2i_ecwa__20160822__20160828__20230611_201420.parquet.gzip  ecwa-raw
# 4   d2i_ecwa__20160829__20160831__20230611_201631.parquet.gzip  ecwa-raw
# 5   d2i_ecwa__20160901__20160907__20230611_110546.parquet.gzip  ecwa-raw
# 6   d2i_ecwa__20160908__20160914__20230611_110929.parquet.gzip  ecwa-raw
# 7   d2i_ecwa__20160915__20160921__20230611_111509.parquet.gzip  ecwa-raw
# 8   d2i_ecwa__20160922__20160928__20230611_111820.parquet.gzip  ecwa-raw
# 9   d2i_ecwa__20160929__20160930__20230611_200041.parquet.gzip  ecwa-raw
# 10  d2i_ecwa__20161001__20161007__20230611_001001.parquet.gzip  ecwa-raw
# 11  d2i_ecwa__20161008__20161014__20230611_001454.parquet.gzip  ecwa-raw
# 12  d2i_ecwa__20161015__20161021__20230611_001736.parquet.gzip  ecwa-raw
# 13  d2i_ecwa__20161022__20161028__20230611_002043.parquet.gzip  ecwa-raw
# 14  d2i_ecwa__20161029__20161031__20230611_002432.parquet.gzip  ecwa-raw
# 15  d2i_ecwa__20161101__20161107__20230530_152206.parquet.gzip  ecwa-raw
# 16  d2i_ecwa__20161108__20161114__20230530_153238.parquet.gzip  ecwa-raw
# 17  d2i_ecwa__20161115__20161121__20230530_161342.parquet.gzip  ecwa-raw
# 18  d2i_ecwa__20161122__20161128__20230604_221113.parquet.gzip  ecwa-raw
# 19  d2i_ecwa__20161129__20161205__20230604_221445.parquet.gzip  ecwa-raw
# 20  d2i_ecwa__20161206__20161212__20230605_161513.parquet.gzip  ecwa-raw
# 21  d2i_ecwa__20161213__20161219__20230605_161840.parquet.gzip  ecwa-raw
# 22  d2i_ecwa__20161220__20161226__20230605_162156.parquet.gzip  ecwa-raw
# 23  d2i_ecwa__20161227__20170102__20230605_162544.parquet.gzip  ecwa-raw
# 24  d2i_ecwa__20170103__20170109__20230605_163214.parquet.gzip  ecwa-raw
# 25  d2i_ecwa__20170110__20170116__20230605_182959.parquet.gzip  ecwa-raw
# 26  d2i_ecwa__20170117__20170123__20230605_183349.parquet.gzip  ecwa-raw
# 27  d2i_ecwa__20170124__20170130__20230605_183616.parquet.gzip  ecwa-raw
# 28  d2i_ecwa__20170131__20170206__20230605_183843.parquet.gzip  ecwa-raw
# 29  d2i_ecwa__20170207__20170213__20230606_115635.parquet.gzip  ecwa-raw
# 30  d2i_ecwa__20170214__20170220__20230606_115920.parquet.gzip  ecwa-raw
# 31  d2i_ecwa__20170221__20170227__20230606_120157.parquet.gzip  ecwa-raw
# 32  d2i_ecwa__20170228__20170306__20230606_185806.parquet.gzip  ecwa-raw
# 33  d2i_ecwa__20170307__20170313__20230606_190156.parquet.gzip  ecwa-raw
# 34  d2i_ecwa__20170314__20170320__20230606_190448.parquet.gzip  ecwa-raw
# 35  d2i_ecwa__20170321__20170327__20230606_190722.parquet.gzip  ecwa-raw
# 36  d2i_ecwa__20170328__20170403__20230606_191150.parquet.gzip  ecwa-raw
# 37  d2i_ecwa__20170404__20170410__20230607_112502.parquet.gzip  ecwa-raw
# 38  d2i_ecwa__20170411__20170417__20230607_112711.parquet.gzip  ecwa-raw
# 39  d2i_ecwa__20170418__20170424__20230607_112923.parquet.gzip  ecwa-raw
# 40  d2i_ecwa__20170425__20170501__20230607_113247.parquet.gzip  ecwa-raw
# 41  d2i_ecwa__20170502__20170508__20230607_113605.parquet.gzip  ecwa-raw
# 42  d2i_ecwa__20170509__20170515__20230608_105750.parquet.gzip  ecwa-raw
# 43  d2i_ecwa__20170516__20170522__20230608_110016.parquet.gzip  ecwa-raw
# 44  d2i_ecwa__20170523__20170529__20230608_110222.parquet.gzip  ecwa-raw
# 45  d2i_ecwa__20170530__20170605__20230608_110431.parquet.gzip  ecwa-raw
# 46  d2i_ecwa__20170606__20170612__20230610_162054.parquet.gzip  ecwa-raw
# 47  d2i_ecwa__20170613__20170619__20230610_162315.parquet.gzip  ecwa-raw
# 48  d2i_ecwa__20170620__20170626__20230610_162520.parquet.gzip  ecwa-raw
# 49  d2i_ecwa__20170627__20170703__20230610_162730.parquet.gzip  ecwa-raw
# 50  d2i_ecwa__20170704__20170710__20230610_163003.parquet.gzip  ecwa-raw
# 51  d2i_ecwa__20170711__20170717__20230610_163229.parquet.gzip  ecwa-raw
# 52  d2i_ecwa__20170718__20170724__20230610_172735.parquet.gzip  ecwa-raw
# 53  d2i_ecwa__20170725__20170731__20230610_173444.parquet.gzip  ecwa-raw
# 54  d2i_ecwa__20170801__20170801__20230610_173641.parquet.gzip  ecwa-raw
#
#      size_mb  \
# 0   4.660864
# 1   5.095205
# 2   5.052166
# 3   4.852887
# 4   2.517590
# 5   4.185168
# 6   4.501941
# 7   5.266326
# 8   4.951720
# 9   1.411386
# 10  4.491890
# 11  4.434698
# 12  4.390024
# 13  4.679543
# 14  1.722868
# 15  4.704754
# 16  4.921709
# 17  5.575957
# 18  5.835802
# 19  6.469955
# 20  6.476081
# 21  6.223205
# 22  3.779628
# 23  3.105586
# 24  4.167440
# 25  3.707910
# 26  3.948315
# 27  4.305809
# 28  3.801771
# 29  3.839108
# 30  3.875040
# 31  3.788718
# 32  3.876007
# 33  3.736998
# 34  3.693063
# 35  3.692482
# 36  3.779546
# 37  3.945833
# 38  3.496119
# 39  3.540592
# 40  4.160729
# 41  3.649929
# 42  3.500749
# 43  4.325023
# 44  3.473806
# 45  3.814128
# 46  3.666802
# 47  3.455317
# 48  3.462677
# 49  3.809763
# 50  3.887948
# 51  4.188950
# 52  4.337407
# 53  4.287689
# 54  0.909663
#
#                                                                                       id  \
# 0   ecwa-raw/d2i_ecwa__20160801__20160807__20230611_200354.parquet.gzip/1686584306817844
# 1   ecwa-raw/d2i_ecwa__20160808__20160814__20230611_200726.parquet.gzip/1686584307242229
# 2   ecwa-raw/d2i_ecwa__20160815__20160821__20230611_201100.parquet.gzip/1686584307682931
# 3   ecwa-raw/d2i_ecwa__20160822__20160828__20230611_201420.parquet.gzip/1686584308098322
# 4   ecwa-raw/d2i_ecwa__20160829__20160831__20230611_201631.parquet.gzip/1686584308482404
# 5   ecwa-raw/d2i_ecwa__20160901__20160907__20230611_110546.parquet.gzip/1686584308908315
# 6   ecwa-raw/d2i_ecwa__20160908__20160914__20230611_110929.parquet.gzip/1686584309285385
# 7   ecwa-raw/d2i_ecwa__20160915__20160921__20230611_111509.parquet.gzip/1686584309721621
# 8   ecwa-raw/d2i_ecwa__20160922__20160928__20230611_111820.parquet.gzip/1686584310161748
# 9   ecwa-raw/d2i_ecwa__20160929__20160930__20230611_200041.parquet.gzip/1686584310500825
# 10  ecwa-raw/d2i_ecwa__20161001__20161007__20230611_001001.parquet.gzip/1686584310932051
# 11  ecwa-raw/d2i_ecwa__20161008__20161014__20230611_001454.parquet.gzip/1686584311384286
# 12  ecwa-raw/d2i_ecwa__20161015__20161021__20230611_001736.parquet.gzip/1686584311799184
# 13  ecwa-raw/d2i_ecwa__20161022__20161028__20230611_002043.parquet.gzip/1686584312219119
# 14  ecwa-raw/d2i_ecwa__20161029__20161031__20230611_002432.parquet.gzip/1686584312564016
# 15  ecwa-raw/d2i_ecwa__20161101__20161107__20230530_152206.parquet.gzip/1686584312983405
# 16  ecwa-raw/d2i_ecwa__20161108__20161114__20230530_153238.parquet.gzip/1686584313397218
# 17  ecwa-raw/d2i_ecwa__20161115__20161121__20230530_161342.parquet.gzip/1686584313840582
# 18  ecwa-raw/d2i_ecwa__20161122__20161128__20230604_221113.parquet.gzip/1686584314269019
# 19  ecwa-raw/d2i_ecwa__20161129__20161205__20230604_221445.parquet.gzip/1686584314720930
# 20  ecwa-raw/d2i_ecwa__20161206__20161212__20230605_161513.parquet.gzip/1686584315169404
# 21  ecwa-raw/d2i_ecwa__20161213__20161219__20230605_161840.parquet.gzip/1686584315616496
# 22  ecwa-raw/d2i_ecwa__20161220__20161226__20230605_162156.parquet.gzip/1686584316030315
# 23  ecwa-raw/d2i_ecwa__20161227__20170102__20230605_162544.parquet.gzip/1686584316440304
# 24  ecwa-raw/d2i_ecwa__20170103__20170109__20230605_163214.parquet.gzip/1686584316871632
# 25  ecwa-raw/d2i_ecwa__20170110__20170116__20230605_182959.parquet.gzip/1686584317286942
# 26  ecwa-raw/d2i_ecwa__20170117__20170123__20230605_183349.parquet.gzip/1686584317668186
# 27  ecwa-raw/d2i_ecwa__20170124__20170130__20230605_183616.parquet.gzip/1686584318085183
# 28  ecwa-raw/d2i_ecwa__20170131__20170206__20230605_183843.parquet.gzip/1686584318504090
# 29  ecwa-raw/d2i_ecwa__20170207__20170213__20230606_115635.parquet.gzip/1686584318968918
# 30  ecwa-raw/d2i_ecwa__20170214__20170220__20230606_115920.parquet.gzip/1686584319341220
# 31  ecwa-raw/d2i_ecwa__20170221__20170227__20230606_120157.parquet.gzip/1686584319745029
# 32  ecwa-raw/d2i_ecwa__20170228__20170306__20230606_185806.parquet.gzip/1686584320158404
# 33  ecwa-raw/d2i_ecwa__20170307__20170313__20230606_190156.parquet.gzip/1686584320570630
# 34  ecwa-raw/d2i_ecwa__20170314__20170320__20230606_190448.parquet.gzip/1686584320939741
# 35  ecwa-raw/d2i_ecwa__20170321__20170327__20230606_190722.parquet.gzip/1686584321354011
# 36  ecwa-raw/d2i_ecwa__20170328__20170403__20230606_191150.parquet.gzip/1686584321749640
# 37  ecwa-raw/d2i_ecwa__20170404__20170410__20230607_112502.parquet.gzip/1686584322098198
# 38  ecwa-raw/d2i_ecwa__20170411__20170417__20230607_112711.parquet.gzip/1686584322511962
# 39  ecwa-raw/d2i_ecwa__20170418__20170424__20230607_112923.parquet.gzip/1686584322907791
# 40  ecwa-raw/d2i_ecwa__20170425__20170501__20230607_113247.parquet.gzip/1686584323288507
# 41  ecwa-raw/d2i_ecwa__20170502__20170508__20230607_113605.parquet.gzip/1686584323702310
# 42  ecwa-raw/d2i_ecwa__20170509__20170515__20230608_105750.parquet.gzip/1686584324107593
# 43  ecwa-raw/d2i_ecwa__20170516__20170522__20230608_110016.parquet.gzip/1686584324531986
# 44  ecwa-raw/d2i_ecwa__20170523__20170529__20230608_110222.parquet.gzip/1686584324958119
# 45  ecwa-raw/d2i_ecwa__20170530__20170605__20230608_110431.parquet.gzip/1686584325370779
# 46  ecwa-raw/d2i_ecwa__20170606__20170612__20230610_162054.parquet.gzip/1686584325781649
# 47  ecwa-raw/d2i_ecwa__20170613__20170619__20230610_162315.parquet.gzip/1686584326152441
# 48  ecwa-raw/d2i_ecwa__20170620__20170626__20230610_162520.parquet.gzip/1686584326529349
# 49  ecwa-raw/d2i_ecwa__20170627__20170703__20230610_162730.parquet.gzip/1686584326951720
# 50  ecwa-raw/d2i_ecwa__20170704__20170710__20230610_163003.parquet.gzip/1686584327367125
# 51  ecwa-raw/d2i_ecwa__20170711__20170717__20230610_163229.parquet.gzip/1686584327783546
# 52  ecwa-raw/d2i_ecwa__20170718__20170724__20230610_172735.parquet.gzip/1686584328200170
# 53  ecwa-raw/d2i_ecwa__20170725__20170731__20230610_173444.parquet.gzip/1686584328634761
# 54  ecwa-raw/d2i_ecwa__20170801__20170801__20230610_173641.parquet.gzip/1686584328913263
#
#                        time_created
# 0  2023-06-12 11:38:26.871000-04:00
# 1  2023-06-12 11:38:27.280000-04:00
# 2  2023-06-12 11:38:27.722000-04:00
# 3  2023-06-12 11:38:28.148000-04:00
# 4  2023-06-12 11:38:28.521000-04:00
# 5  2023-06-12 11:38:28.945000-04:00
# 6  2023-06-12 11:38:29.325000-04:00
# 7  2023-06-12 11:38:29.759000-04:00
# 8  2023-06-12 11:38:30.201000-04:00
# 9  2023-06-12 11:38:30.539000-04:00
# 10 2023-06-12 11:38:30.972000-04:00
# 11 2023-06-12 11:38:31.438000-04:00
# 12 2023-06-12 11:38:31.839000-04:00
# 13 2023-06-12 11:38:32.258000-04:00
# 14 2023-06-12 11:38:32.601000-04:00
# 15 2023-06-12 11:38:33.022000-04:00
# 16 2023-06-12 11:38:33.434000-04:00
# 17 2023-06-12 11:38:33.879000-04:00
# 18 2023-06-12 11:38:34.306000-04:00
# 19 2023-06-12 11:38:34.760000-04:00
# 20 2023-06-12 11:38:35.209000-04:00
# 21 2023-06-12 11:38:35.653000-04:00
# 22 2023-06-12 11:38:36.069000-04:00
# 23 2023-06-12 11:38:36.489000-04:00
# 24 2023-06-12 11:38:36.911000-04:00
# 25 2023-06-12 11:38:37.326000-04:00
# 26 2023-06-12 11:38:37.725000-04:00
# 27 2023-06-12 11:38:38.125000-04:00
# 28 2023-06-12 11:38:38.560000-04:00
# 29 2023-06-12 11:38:39.008000-04:00
# 30 2023-06-12 11:38:39.381000-04:00
# 31 2023-06-12 11:38:39.784000-04:00
# 32 2023-06-12 11:38:40.197000-04:00
# 33 2023-06-12 11:38:40.609000-04:00
# 34 2023-06-12 11:38:40.978000-04:00
# 35 2023-06-12 11:38:41.403000-04:00
# 36 2023-06-12 11:38:41.789000-04:00
# 37 2023-06-12 11:38:42.138000-04:00
# 38 2023-06-12 11:38:42.551000-04:00
# 39 2023-06-12 11:38:42.947000-04:00
# 40 2023-06-12 11:38:43.337000-04:00
# 41 2023-06-12 11:38:43.742000-04:00
# 42 2023-06-12 11:38:44.147000-04:00
# 43 2023-06-12 11:38:44.572000-04:00
# 44 2023-06-12 11:38:44.996000-04:00
# 45 2023-06-12 11:38:45.410000-04:00
# 46 2023-06-12 11:38:45.821000-04:00
# 47 2023-06-12 11:38:46.190000-04:00
# 48 2023-06-12 11:38:46.568000-04:00
# 49 2023-06-12 11:38:46.990000-04:00
# 50 2023-06-12 11:38:47.409000-04:00
# 51 2023-06-12 11:38:47.823000-04:00
# 52 2023-06-12 11:38:48.240000-04:00
# 53 2023-06-12 11:38:48.674000-04:00
# 54 2023-06-12 11:38:48.953000-04:00

# %% [markdown]
# [Delete all file](https://github.com/googleapis/python-storage/blob/main/samples/snippets/storage_delete_file.py)s in specified bucket

# %%
#| echo: true
bucket = storage_client.bucket(bucket_name)
for k, row in df_blobs.iterrows():
    blob = bucket.blob(row['name'])
    blob.reload()
    generation_match_precondition = blob.generation
    blob.delete(if_generation_match=generation_match_precondition)
    print(f"Delete blob {k+1}/{len(df_blobs)}, {row['name']}, from bucket {bucket_name}")
# Out:
# Delete blob d2i_ecwa__20160801__20160807__20230611_200354.parquet.gzip
# Delete blob d2i_ecwa__20160808__20160814__20230611_200726.parquet.gzip
# Delete blob d2i_ecwa__20160815__20160821__20230611_201100.parquet.gzip
# Delete blob d2i_ecwa__20160822__20160828__20230611_201420.parquet.gzip
# Delete blob d2i_ecwa__20160829__20160831__20230611_201631.parquet.gzip
# Delete blob d2i_ecwa__20160901__20160907__20230611_110546.parquet.gzip
# Delete blob d2i_ecwa__20160908__20160914__20230611_110929.parquet.gzip
# Delete blob d2i_ecwa__20160915__20160921__20230611_111509.parquet.gzip
# Delete blob d2i_ecwa__20160922__20160928__20230611_111820.parquet.gzip
# Delete blob d2i_ecwa__20160929__20160930__20230611_200041.parquet.gzip
# Delete blob d2i_ecwa__20161001__20161007__20230611_001001.parquet.gzip
# Delete blob d2i_ecwa__20161008__20161014__20230611_001454.parquet.gzip
# Delete blob d2i_ecwa__20161015__20161021__20230611_001736.parquet.gzip
# Delete blob d2i_ecwa__20161022__20161028__20230611_002043.parquet.gzip
# Delete blob d2i_ecwa__20161029__20161031__20230611_002432.parquet.gzip
# Delete blob d2i_ecwa__20161101__20161107__20230530_152206.parquet.gzip
# Delete blob d2i_ecwa__20161108__20161114__20230530_153238.parquet.gzip
# Delete blob d2i_ecwa__20161115__20161121__20230530_161342.parquet.gzip
# Delete blob d2i_ecwa__20161122__20161128__20230604_221113.parquet.gzip
# Delete blob d2i_ecwa__20161129__20161205__20230604_221445.parquet.gzip
# Delete blob d2i_ecwa__20161206__20161212__20230605_161513.parquet.gzip
# Delete blob d2i_ecwa__20161213__20161219__20230605_161840.parquet.gzip
# Delete blob d2i_ecwa__20161220__20161226__20230605_162156.parquet.gzip
# Delete blob d2i_ecwa__20161227__20170102__20230605_162544.parquet.gzip
# Delete blob d2i_ecwa__20170103__20170109__20230605_163214.parquet.gzip
# Delete blob d2i_ecwa__20170110__20170116__20230605_182959.parquet.gzip
# Delete blob d2i_ecwa__20170117__20170123__20230605_183349.parquet.gzip
# Delete blob d2i_ecwa__20170124__20170130__20230605_183616.parquet.gzip
# Delete blob d2i_ecwa__20170131__20170206__20230605_183843.parquet.gzip
# Delete blob d2i_ecwa__20170207__20170213__20230606_115635.parquet.gzip
# Delete blob d2i_ecwa__20170214__20170220__20230606_115920.parquet.gzip
# Delete blob d2i_ecwa__20170221__20170227__20230606_120157.parquet.gzip
# Delete blob d2i_ecwa__20170228__20170306__20230606_185806.parquet.gzip
# Delete blob d2i_ecwa__20170307__20170313__20230606_190156.parquet.gzip
# Delete blob d2i_ecwa__20170314__20170320__20230606_190448.parquet.gzip
# Delete blob d2i_ecwa__20170321__20170327__20230606_190722.parquet.gzip
# Delete blob d2i_ecwa__20170328__20170403__20230606_191150.parquet.gzip
# Delete blob d2i_ecwa__20170404__20170410__20230607_112502.parquet.gzip
# Delete blob d2i_ecwa__20170411__20170417__20230607_112711.parquet.gzip
# Delete blob d2i_ecwa__20170418__20170424__20230607_112923.parquet.gzip
# Delete blob d2i_ecwa__20170425__20170501__20230607_113247.parquet.gzip
# Delete blob d2i_ecwa__20170502__20170508__20230607_113605.parquet.gzip
# Delete blob d2i_ecwa__20170509__20170515__20230608_105750.parquet.gzip
# Delete blob d2i_ecwa__20170516__20170522__20230608_110016.parquet.gzip
# Delete blob d2i_ecwa__20170523__20170529__20230608_110222.parquet.gzip
# Delete blob d2i_ecwa__20170530__20170605__20230608_110431.parquet.gzip
# Delete blob d2i_ecwa__20170606__20170612__20230610_162054.parquet.gzip
# Delete blob d2i_ecwa__20170613__20170619__20230610_162315.parquet.gzip
# Delete blob d2i_ecwa__20170620__20170626__20230610_162520.parquet.gzip
# Delete blob d2i_ecwa__20170627__20170703__20230610_162730.parquet.gzip
# Delete blob d2i_ecwa__20170704__20170710__20230610_163003.parquet.gzip
# Delete blob d2i_ecwa__20170711__20170717__20230610_163229.parquet.gzip
# Delete blob d2i_ecwa__20170718__20170724__20230610_172735.parquet.gzip
# Delete blob d2i_ecwa__20170725__20170731__20230610_173444.parquet.gzip
# Delete blob d2i_ecwa__20170801__20170801__20230610_173641.parquet.gzip

# %% [markdown]
# Verify that no files are found in specified bucket

# %%
#| echo: true
blobs = list(storage_client.list_blobs(bucket_name))
try:
    assert not blobs
    print(f"Found no files in bucket {bucket_name}")
except AssertionError as e:
    print(f"{str(e)}Found files in bucket {bucket_name} that were not deleted")
# Out:
# Found no files in bucket ecwa-raw

# %% [markdown]
# ### Buckets

# %% [markdown]
# [Delete specified bucket](https://github.com/googleapis/python-storage/blob/main/samples/snippets/storage_delete_bucket.py)

# %%
try:
    bucket = storage_client.get_bucket(bucket_name)
    bucket.delete()
    print(f"Deleted bucket {bucket_name}")
except Exception as e:
    if "you already own it" in str(e):
        print(f"Bucket {bucket_name} already exists")
    else:
        print(f"Got response: {str(e)}")
# Out:
# Deleted bucket ecwa-raw

# %% [markdown]
# Verify that specified bucket name is not found in [list of buckets](https://github.com/googleapis/python-storage/blob/main/samples/snippets/storage_list_buckets.py) in Google Cloud project

# %%
#| echo: true
buckets = list(storage_client.list_buckets())
if buckets:
    df_buckets = pd.DataFrame.from_records(
        [
            {
                "bucket": b.name,
                "time_created": b.time_created,
            }
            for b in buckets
        ]
    )
    try:
        assert df_buckets.query(f"bucket = '{bucket_name}'").empty
        print(f"Did not find bucket {bucket_name}")
    except AssertionError as e:
        print(f"{str(e)}Found bucket {bucket_name}")
        print("Showing specified bucket in list of buckets")
        display(df_buckets.query(f"bucket = '{bucket_name}'"))
else:
    print("Found no buckets")
# Out:
# Found no buckets

# %% [markdown]
# ## Local Storage

# %% [markdown]
# ### Files

# %%
for k, f in enumerate(raw_data_files):
    if os.path.exists(f):
        os.remove(f)
        print(f"Deleted local file {k+1}/{len(raw_data_files):,} at {os.path.basename(f)}")
    else:
        print(f"File {f} does not exist")
# Out:
# Deleted local file 1/55 at d2i_ecwa__20160801__20160807__20230611_200354.parquet.gzip
# Deleted local file 2/55 at d2i_ecwa__20160808__20160814__20230611_200726.parquet.gzip
# Deleted local file 3/55 at d2i_ecwa__20160815__20160821__20230611_201100.parquet.gzip
# Deleted local file 4/55 at d2i_ecwa__20160822__20160828__20230611_201420.parquet.gzip
# Deleted local file 5/55 at d2i_ecwa__20160829__20160831__20230611_201631.parquet.gzip
# Deleted local file 6/55 at d2i_ecwa__20160901__20160907__20230611_110546.parquet.gzip
# Deleted local file 7/55 at d2i_ecwa__20160908__20160914__20230611_110929.parquet.gzip
# Deleted local file 8/55 at d2i_ecwa__20160915__20160921__20230611_111509.parquet.gzip
# Deleted local file 9/55 at d2i_ecwa__20160922__20160928__20230611_111820.parquet.gzip
# Deleted local file 10/55 at d2i_ecwa__20160929__20160930__20230611_200041.parquet.gzip
# Deleted local file 11/55 at d2i_ecwa__20161001__20161007__20230611_001001.parquet.gzip
# Deleted local file 12/55 at d2i_ecwa__20161008__20161014__20230611_001454.parquet.gzip
# Deleted local file 13/55 at d2i_ecwa__20161015__20161021__20230611_001736.parquet.gzip
# Deleted local file 14/55 at d2i_ecwa__20161022__20161028__20230611_002043.parquet.gzip
# Deleted local file 15/55 at d2i_ecwa__20161029__20161031__20230611_002432.parquet.gzip
# Deleted local file 16/55 at d2i_ecwa__20161101__20161107__20230530_152206.parquet.gzip
# Deleted local file 17/55 at d2i_ecwa__20161108__20161114__20230530_153238.parquet.gzip
# Deleted local file 18/55 at d2i_ecwa__20161115__20161121__20230530_161342.parquet.gzip
# Deleted local file 19/55 at d2i_ecwa__20161122__20161128__20230604_221113.parquet.gzip
# Deleted local file 20/55 at d2i_ecwa__20161129__20161205__20230604_221445.parquet.gzip
# Deleted local file 21/55 at d2i_ecwa__20161206__20161212__20230605_161513.parquet.gzip
# Deleted local file 22/55 at d2i_ecwa__20161213__20161219__20230605_161840.parquet.gzip
# Deleted local file 23/55 at d2i_ecwa__20161220__20161226__20230605_162156.parquet.gzip
# Deleted local file 24/55 at d2i_ecwa__20161227__20170102__20230605_162544.parquet.gzip
# Deleted local file 25/55 at d2i_ecwa__20170103__20170109__20230605_163214.parquet.gzip
# Deleted local file 26/55 at d2i_ecwa__20170110__20170116__20230605_182959.parquet.gzip
# Deleted local file 27/55 at d2i_ecwa__20170117__20170123__20230605_183349.parquet.gzip
# Deleted local file 28/55 at d2i_ecwa__20170124__20170130__20230605_183616.parquet.gzip
# Deleted local file 29/55 at d2i_ecwa__20170131__20170206__20230605_183843.parquet.gzip
# Deleted local file 30/55 at d2i_ecwa__20170207__20170213__20230606_115635.parquet.gzip
# Deleted local file 31/55 at d2i_ecwa__20170214__20170220__20230606_115920.parquet.gzip
# Deleted local file 32/55 at d2i_ecwa__20170221__20170227__20230606_120157.parquet.gzip
# Deleted local file 33/55 at d2i_ecwa__20170228__20170306__20230606_185806.parquet.gzip
# Deleted local file 34/55 at d2i_ecwa__20170307__20170313__20230606_190156.parquet.gzip
# Deleted local file 35/55 at d2i_ecwa__20170314__20170320__20230606_190448.parquet.gzip
# Deleted local file 36/55 at d2i_ecwa__20170321__20170327__20230606_190722.parquet.gzip
# Deleted local file 37/55 at d2i_ecwa__20170328__20170403__20230606_191150.parquet.gzip
# Deleted local file 38/55 at d2i_ecwa__20170404__20170410__20230607_112502.parquet.gzip
# Deleted local file 39/55 at d2i_ecwa__20170411__20170417__20230607_112711.parquet.gzip
# Deleted local file 40/55 at d2i_ecwa__20170418__20170424__20230607_112923.parquet.gzip
# Deleted local file 41/55 at d2i_ecwa__20170425__20170501__20230607_113247.parquet.gzip
# Deleted local file 42/55 at d2i_ecwa__20170502__20170508__20230607_113605.parquet.gzip
# Deleted local file 43/55 at d2i_ecwa__20170509__20170515__20230608_105750.parquet.gzip
# Deleted local file 44/55 at d2i_ecwa__20170516__20170522__20230608_110016.parquet.gzip
# Deleted local file 45/55 at d2i_ecwa__20170523__20170529__20230608_110222.parquet.gzip
# Deleted local file 46/55 at d2i_ecwa__20170530__20170605__20230608_110431.parquet.gzip
# Deleted local file 47/55 at d2i_ecwa__20170606__20170612__20230610_162054.parquet.gzip
# Deleted local file 48/55 at d2i_ecwa__20170613__20170619__20230610_162315.parquet.gzip
# Deleted local file 49/55 at d2i_ecwa__20170620__20170626__20230610_162520.parquet.gzip
# Deleted local file 50/55 at d2i_ecwa__20170627__20170703__20230610_162730.parquet.gzip
# Deleted local file 51/55 at d2i_ecwa__20170704__20170710__20230610_163003.parquet.gzip
# Deleted local file 52/55 at d2i_ecwa__20170711__20170717__20230610_163229.parquet.gzip
# Deleted local file 53/55 at d2i_ecwa__20170718__20170724__20230610_172735.parquet.gzip
# Deleted local file 54/55 at d2i_ecwa__20170725__20170731__20230610_173444.parquet.gzip
# Deleted local file 55/55 at d2i_ecwa__20170801__20170801__20230610_173641.parquet.gzip
